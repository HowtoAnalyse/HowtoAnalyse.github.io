# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Regular expressions (urrggghhhhhhhhh) for handling string features
import re

# LightGBM
import lightgbm as lgb

# sklearn tools for model training and assesment
from sklearn.model_selection import train_test_split
from sklearn.metrics import (roc_curve, auc, accuracy_score)
from sklearn.model_selection import GridSearchCV


#%% Import data
# Import both data sets
trainRaw = pd.read_csv('train.csv')
testRaw = pd.read_csv('test.csv')

# And concatonate together
nTrain = trainRaw.shape[0]
full = pd.concat([trainRaw, testRaw], axis=0)

# %%
def ADSplit(s):
    """
    Function to try and extract cabin letter and number from the cabin column.
    Runs a regular expression that finds letters and numbers in the 
    string. These are held in match.group, if they exist.
    """

    match = re.match(r"([a-z]+)([0-9]+)", s, re.I)
    
    try:
        letter = match.group(1)
    except:
        letter = ''
    
    try:
        number = match.group(2)
    except:
        number = 9999

    return letter, number


def DR(s):
    """
    From the cabin string, try and extract letter, number, and number of cabins
    """
    # Check contents
    if isinstance(s, (int, float)):
        # If field is empty, return nothing
        letter = ''
        number = ''
        nRooms = 9999
    else:
        # If field isn't empty, split sting on space. Some strings contain 
        # multiple cabins.
        s = s.split(' ')
        # Count the cabins based on number of splits
        nRooms = len(s)
        # Just take first cabin for letter/number extraction
        s = s[0]
        
        letter, number = ADSplit(s)
   
    return [letter, number, nRooms]

# Apply DR function to each cell in Cabin column using pandas apply method.    
out = full['Cabin'].apply(DR)
# Outout tuple with 3 values for each row, convert this to pandas df
out = out.apply(pd.Series)
# And name the columns
out.columns = ['CL', 'CN', 'nC']
    
# Then concatenate these columns to the dataset
full = pd.concat([full, out], axis=1)
    

#%% Family 
# Add some family features directly to new columns in the dataset
# Size
full['fSize'] = full['SibSp'] + full['Parch'] + 1
# Ratio
full['fRatio'] = (full['Parch']+1) / (full['SibSp']+ 1)
# Adult?
full['Adult'] = full['Age']>18    


#%% Names
# Extract titles from Name column, standardise
titleDict = {
    "Capt": "Officer",
    "Col": "Officer",
    "Major": "Officer",
    "Jonkheer": "Sir",
    "Don": "Sir",
    "Sir": "Sir",
    "Dr": "Dr",
    "Rev": "Rev",
    "theCountess": "Lady",
    "Dona": "Lady",
    "Mme": "Mrs",
    "Mlle": "Miss",
    "Ms": "Mrs",
    "Mr": "Mr",
    "Mrs": "Mrs",
    "Miss": "Miss",
    "Master": "Master",
    "Lady": "Lady"
}


def splitName(s, titleDict):
    """
    Extract title from name, replace with value in title dictionary. Also 
    return surname.
    """
    
    # Remove '.' from name string
    s = s.replace('.', '')
    # Split on spaces
    s = s.split(' ')
    # get surname
    surname = s[0]

    # Get title - loop over titleDict, if s matches a key, take the 
    # corresponding value as the title
    title = [t for k,t in titleDict.items() if str(k) in s]
   
    # If no matching keys in title dict, use 'Other'.
    if title == []:
        title = 'Other'
    else:
        # Title is a list, so extract contents
        title = title[0]
    
    # Return surname (stripping remaining ',') and title as string
    return surname.strip(','), title


# Apply functions to df and concatenate new columns as before
out = full['Name'].apply(splitName, args=[titleDict])
out = out.apply(pd.Series)
out.columns = ['Surname', 'Title']
  
full = pd.concat([full, out], axis=1)


#%% Categorical columns
# List of categorical columns to recode
catCols = ['Sex', 'Embarked', 'CL', 'CN', 'Surname', 'Title']

# Recode
for c in catCols:
    # Convert column to pd.Categotical
    full[c] = pd.Categorical(full[c])
    # Extract the cat.codes and replace the column with these
    full[c] = full[c].cat.codes
    # Convert the cat codes to categotical...    
    full[c] = pd.Categorical(full[c])


# Generate a logical index of categorical columns to maybe use with LightGBM later
catCols = [i for i,v in enumerate(full.dtypes) if str(v)=='category']


#%% Age
# Replace missing age values with median. 
# See ither kernels for more sophisticated ways of doing this!
full.loc[full.Age.isnull(), 'Age'] = np.median(full['Age'].loc[full.Age.notnull()])

# %%
train = full.iloc[0:nTrain,:]
test = full.iloc[nTrain::,:]

# %%
def prepLGB(data, classCol = '', IDCol = '', fDrop = []):
    
        # Drop class column
        if classCol != '':
            labels = data[classCol]
            fDrop = fDrop + [classCol]
        else:
            labels = []
    
        if IDCol != '':
            IDs = data[IDCol]
        else:
            IDs = []

        if fDrop != []:
           data =  data.drop(fDrop, axis=1)
       
        # Create LGB mats        
        lData = lgb.Dataset(data, label=labels, free_raw_data=False, 
                            feature_name=list(data.columns),
                            categorical_feature = 'auto')
        
        return lData, labels, IDs, data

        
# Specify columns to drop
fDrop = ['Ticket', 'Cabin', 'Name']

# Split training data in to training and validation sets. 
# Validation set is used for early stopping.
trainData, validData = train_test_split(train, test_size=0.3, stratify=train.Survived)

# Prepare the data sets
trainDataL, trainLabels, trainIDs, trainData = prepLGB(trainData, 
                                                 classCol = 'Survived', 
                                                 IDCol = 'PassengerId',
                                                 fDrop = fDrop)
                                                 
validDataL, validLabels, validIDs, validData = prepLGB(validData, 
                                                 classCol = 'Survived', 
                                                 IDCol = 'PassengerId',
                                                 fDrop = fDrop)

testDataL, _, _ , testData = prepLGB(test, 
                                 classCol = 'Survived', 
                                 IDCol = 'PassengerId',
                                 fDrop = fDrop)
                                 
# Prepare data set using all the training data
allTrainDataL, allTrainLabels, _ , allTrainData = prepLGB(train, 
                                                 classCol = 'Survived', 
                                                 IDCol = 'PassengerId',
                                                 fDrop = fDrop)

# %%
params = {'boosting_type': 'gbdt',
          'max_depth' : -1,
          'objective': 'binary', 
          'nthread': 5, # Updated from nthread
          'num_leaves': 64, 
          'learning_rate': 0.05, 
          'max_bin': 512, 
          'subsample_for_bin': 200,
          'subsample': 1, 
          'subsample_freq': 1, 
          'colsample_bytree': 0.8, 
          'reg_alpha': 5, 
          'reg_lambda': 10,
          'min_split_gain': 0.5, 
          'min_child_weight': 1, 
          'min_child_samples': 5, 
          'scale_pos_weight': 1,
          'num_class' : 1,
          'metric' : 'binary_error'}

# Create parameters to search
gridParams = {
    'learning_rate': [0.001,0.005,0.01],
    'n_estimators': [16,24,100],
    'num_leaves': [2**6,2**5],
    'boosting_type' : ['gbdt'],
    'objective' : ['binary'],
    'random_state' : [501], # Updated from 'seed'
    'colsample_bytree' : [0.60, 0.64],
    'subsample' : [0.75,0.9, 0.95],
    'reg_alpha' : [1,1.2],
    'reg_lambda' : [1.4,2],
    }

# Create classifier to use. Note that parameters have to be input manually
# not as a dict!
mdl = lgb.LGBMClassifier(boosting_type= 'gbdt', 
          objective = 'binary', 
          n_jobs = 5, # Updated from 'nthread' 
          verbosity = 10,
          max_depth = params['max_depth'],
          max_bin = params['max_bin'], 
          subsample_for_bin = params['subsample_for_bin'],
          subsample = params['subsample'], 
          subsample_freq = params['subsample_freq'], 
          min_split_gain = params['min_split_gain'], 
          min_child_weight = params['min_child_weight'], 
          min_child_samples = params['min_child_samples'], 
          scale_pos_weight = params['scale_pos_weight'])

# To view the default model params:
mdl.get_params().keys()

# Create the grid
grid = GridSearchCV(mdl, gridParams, verbose=1, cv=5, n_jobs=-1)

# %%
# Run the grid
grid.fit(allTrainData, allTrainLabels)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed:   40.0s
# [Parallel(n_jobs=-1)]: Done 1234 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 2160 out of 2160 | elapsed:  1.9min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LGBMClassifier(boosting_type='gbdt', colsample_bytree=1.0, learning_rate=0.1,
#         max_bin=512, max_depth=-1, min_child_samples=5, min_child_weight=1,
#         min_split_gain=0.5, n_estimators=10, n_jobs=5, num_leaves=31,
#         objective='binary', random_state=0, reg_alpha=0.0, reg_lambda=0.0,
#         scale_pos_weight=1, silent=True, subsample=1,
#         subsample_for_bin=200, subsample_freq=1, verbosity=10),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'n_estimators': [16, 24, 100], 'random_state': [501], 'objective': ['binary'], 'num_leaves': [64, 32], 'reg_alpha': [1, 1.2], 'reg_lambda': [1.4, 2], 'subsample': [0.75, 0.9, 0.95], 'colsample_bytree': [0.6, 0.64], 'learning_rate': [0.001, 0.005, 0.01], 'boosting_type': ['gbdt']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=1)

# %%
# Print the best parameters found
print(grid.best_params_)
print(grid.best_score_)

# Using parameters already set above, replace in the best from the grid search
params['colsample_bytree'] = grid.best_params_['colsample_bytree']
params['learning_rate'] = grid.best_params_['learning_rate'] 
# params['max_bin'] = grid.best_params_['max_bin']
params['num_leaves'] = grid.best_params_['num_leaves']
params['reg_alpha'] = grid.best_params_['reg_alpha']
params['reg_lambda'] = grid.best_params_['reg_lambda']
params['subsample'] = grid.best_params_['subsample']
# params['subsample_for_bin'] = grid.best_params_['subsample_for_bin']

print('Fitting with params: ')
print(params)

# Kit k models with early-stopping on different training/validation splits
k = 12;
predsValid = 0 
predsTrain = 0
predsTest = 0
for i in range(0, k): 
    print('Fitting model', k)
    
    # Prepare the data set for fold
    trainData, validData = train_test_split(train, test_size=0.4, stratify=train.Survived)
    trainDataL, trainLabels, trainIDs, trainData = prepLGB(trainData, 
                                                     classCol = 'Survived', 
                                                     IDCol = 'PassengerId',
                                                     fDrop = fDrop)
    validDataL, validLabels, validIDs, validData = prepLGB(validData, 
                                                     classCol = 'Survived', 
                                                     IDCol = 'PassengerId',
                                                     fDrop = fDrop)
    # Train     
    gbm = lgb.train(params, 
                    trainDataL, 
                    100000, 
                    valid_sets=[trainDataL, validDataL],
                    early_stopping_rounds = 50,
                    verbose_eval=4)

    # Plot importance
    lgb.plot_importance(gbm)
    plt.show()
    
    # Predict
    predsValid += gbm.predict(validData, num_iteration=gbm.best_iteration)/k
    predsTrain += gbm.predict(trainData, num_iteration=gbm.best_iteration)/k
    predsTest += gbm.predict(testData, num_iteration=gbm.best_iteration)/k

# Print assessment
# assessMod(predsTrain, trainLabels, predsValid=predsValid, yValid= validLabels, 
#           report=True, plot=True)               

# Save submission
sub = pd.DataFrame()
sub['PassengerId'] = test['PassengerId']
sub['Survived'] = np.int32(predsTest>0.5)
# Out:
# {'n_estimators': 100, 'random_state': 501, 'objective': 'binary', 'num_leaves': 64, 'reg_alpha': 1.2, 'reg_lambda': 1.4, 'subsample': 0.75, 'colsample_bytree': 0.6, 'learning_rate': 0.001, 'boosting_type': 'gbdt'}
# 0.818181818182
# Fitting with params:
# {'num_class': 1, 'min_split_gain': 0.5, 'scale_pos_weight': 1, 'reg_lambda': 1.4, 'reg_alpha': 1.2, 'min_child_samples': 5, 'subsample_freq': 1, 'max_depth': -1, 'boosting_type': 'gbdt', 'colsample_bytree': 0.6, 'num_leaves': 64, 'min_child_weight': 1, 'objective': 'binary', 'max_bin': 512, 'metric': 'binary_error', 'nthread': 5, 'subsample': 0.75, 'learning_rate': 0.001, 'subsample_for_bin': 200}
# Fitting model 12
# Training until validation scores don't improve for 50 rounds.
# [4]	training's binary_error: 0.168539	valid_1's binary_error: 0.187675
# [8]	training's binary_error: 0.170412	valid_1's binary_error: 0.182073
# [12]	training's binary_error: 0.155431	valid_1's binary_error: 0.176471
# [16]	training's binary_error: 0.151685	valid_1's binary_error: 0.184874
# [20]	training's binary_error: 0.159176	valid_1's binary_error: 0.179272
# [24]	training's binary_error: 0.155431	valid_1's binary_error: 0.182073
# [28]	training's binary_error: 0.155431	valid_1's binary_error: 0.182073
# [32]	training's binary_error: 0.155431	valid_1's binary_error: 0.182073
# [36]	training's binary_error: 0.157303	valid_1's binary_error: 0.182073
# [40]	training's binary_error: 0.157303	valid_1's binary_error: 0.182073
# [44]	training's binary_error: 0.157303	valid_1's binary_error: 0.179272
# [48]	training's binary_error: 0.162921	valid_1's binary_error: 0.182073
# [52]	training's binary_error: 0.162921	valid_1's binary_error: 0.182073
# Early stopping, best iteration is:
# [5]	training's binary_error: 0.164794	valid_1's binary_error: 0.173669
# Fitting model 12
# Training until validation scores don't improve for 50 rounds.
# [4]	training's binary_error: 0.161049	valid_1's binary_error: 0.165266
# [8]	training's binary_error: 0.168539	valid_1's binary_error: 0.168067
# [12]	training's binary_error: 0.153558	valid_1's binary_error: 0.156863
# [16]	training's binary_error: 0.142322	valid_1's binary_error: 0.165266
# [20]	training's binary_error: 0.153558	valid_1's binary_error: 0.162465
# [24]	training's binary_error: 0.146067	valid_1's binary_error: 0.176471
# [28]	training's binary_error: 0.157303	valid_1's binary_error: 0.165266
# [32]	training's binary_error: 0.14794	valid_1's binary_error: 0.159664
# [36]	training's binary_error: 0.149813	valid_1's binary_error: 0.165266
# [40]	training's binary_error: 0.14794	valid_1's binary_error: 0.159664
# [44]	training's binary_error: 0.153558	valid_1's binary_error: 0.162465
# [48]	training's binary_error: 0.159176	valid_1's binary_error: 0.162465
# [52]	training's binary_error: 0.161049	valid_1's binary_error: 0.159664
# [56]	training's binary_error: 0.162921	valid_1's binary_error: 0.170868
# [60]	training's binary_error: 0.164794	valid_1's binary_error: 0.168067
# Early stopping, best iteration is:
# [11]	training's binary_error: 0.151685	valid_1's binary_error: 0.156863
# Fitting model 12
# Training until validation scores don't improve for 50 rounds.
# [4]	training's binary_error: 0
# Training until validation scores don't improve for 50 rounds.
# [4]	training's binary_error: 0.161049	valid_1's binary_error: 0.22409
# [8]	training's binary_error: 0.153558	valid_1's binary_error: 0.221289
# [12]	training's binary_error: 0.151685	valid_1's binary_error: 0.221289
# [16]	training's binary_error: 0.146067	valid_1's binary_error: 0.212885
# [20]	training's binary_error: 0.146067	valid_1's binary_error: 0.210084
# [24]	training's binary_error: 0.146067	valid_1's binary_error: 0.210084
# [28]	training's binary_error: 0.151685	valid_1's binary_error: 0.215686
# [32]	training's binary_error: 0.149813	valid_1's binary_error: 0.215686
# [36]	training's binary_error: 0.153558	valid_1's binary_error: 0.215686
# [40]	training's binary_error: 0.151685	valid_1's binary_error: 0.221289
# [44]	training's binary_error: 0.151685	valid_1's binary_error: 0.215686
# [48]	training's binary_error: 0.149813	valid_1's binary_error: 0.212885
# [52]	training's binary_error: 0.149813	valid_1's binary_error: 0.215686
# [56]	training's binary_error: 0.151685	valid_1's binary_error: 0.212885
# Early stopping, best iteration is:
# [9]	training's binary_error: 0.129213	valid_1's binary_error: 0.210084
# Fitting model 12
# Training until validation scores don't improve for 50 rounds.
# [4]	training's binary_error: 0.155431	valid_1's binary_error: 0.201681
# [8]	training's binary_error: 0.146067	valid_1's binary_error: 0.207283
# [12]	training's binary_error: 0.159176	valid_1's binary_error: 0.204482
# [16]	training's binary_error: 0.142322	valid_1's binary_error: 0.190476
# [20]	training's binary_error: 0.157303	valid_1's binary_error: 0.193277
# [24]	training's binary_error: 0.14794	valid_1's binary_error: 0.184874
# [28]	training's binary_error: 0.14794	valid_1's binary_error: 0.190476
# [32]	training's binary_error: 0.149813	valid_1's binary_error: 0.190476
# [36]	training's binary_error: 0.151685	valid_1's binary_error: 0.190476
# [40]	training's binary_error: 0.14794	valid_1's binary_error: 0.187675
# [44]	training's binary_error: 0.153558	valid_1's binary_error: 0.196078
# [48]	training's binary_error: 0.157303	valid_1's binary_error: 0.193277
# [52]	training's binary_error: 0.157303	valid_1's binary_error: 0.193277
# Early stopping, best iteration is:
# [2]	training's binary_error: 0.185393	valid_1's binary_error: 0.182073
# Fitting model 12
# Training until validation scores don't improve for 50 rounds.
# [4]	training's binary_error: 0.142322	valid_1's binary_error: 0.187675
# [8]	training's binary_error: 0.144195	valid_1's binary_error: 0.196078
# [12]	training's binary_error: 0.155431	valid_1's binary_error: 0.193277
# [16]	training's binary_error: 0.144195	valid_1's binary_error: 0.19888
# [20]	training's binary_error: 0.14794	valid_1's binary_error: 0.193277
# [24]	training's binary_error: 0.138577	valid_1's binary_error: 0.179272
# [28]	training's binary_error: 0.149813	valid_1's binary_error: 0.196078
# [32]	training's binary_error: 0.149813	valid_1's binary_error: 0.187675
# [36]	training's binary_error: 0.14794	valid_1's binary_error: 0.193277
# [40]	training's binary_error: 0.14794	valid_1's binary_error: 0.187675
# [44]	training's binary_error: 0.14794	valid_1's binary_error: 0.193277
# [48]	training's binary_error: 0.155431	valid_1's binary_error: 0.190476
# [52]	training's binary_error: 0.153558	valid_1's binary_error: 0.193277
# [56]	training's binary_error: 0.157303	valid_1's binary_error: 0.187675
# [60]	training's binary_error: 0.159176	valid_1's binary_error: 0.190476
# [64]	training's binary_error: 0.153558	valid_1's binary_error: 0.193277
# Early stopping, best iteration is:
# [15]	training's binary_error: 0.134831	valid_1's binary_error: 0.19888
# Fitting model 12
# Training until validation scores don't improve for 50 rounds.
# [4]	training's binary_error: 0.157303	valid_1's binary_error: 0.215686
# [8]	training's binary_error: 0.153558	valid_1's binary_error: 0.207283
# [12]	training's binary_error: 0.155431	valid_1's binary_error: 0.215686
# [16]	training's binary_error: 0.14794	valid_1's binary_error: 0.210084
# [20]	training's binary_error: 0.149813	valid_1's binary_error: 0.19888
# [24]	training's binary_error: 0.138577	valid_1's binary_error: 0.193277
# [28]	training's binary_error: 0.153558	valid_1's binary_error: 0.193277
# [32]	training's binary_error: 0.149813	valid_1's binary_error: 0.193277
# [36]	training's binary_error: 0.146067	valid_1's binary_error: 0.193277
# [40]	training's binary_error: 0.144195	valid_1's binary_error: 0.193277
# [44]	training's binary_error: 0.149813	valid_1's binary_error: 0.19888
# [48]	training's binary_error: 0.157303	valid_1's binary_error: 0.19888
# [52]	training's binary_error: 0.157303	valid_1's binary_error: 0.19888
# [56]	training's binary_error: 0.155431	valid_1's binary_error: 0.196078
# [60]	training's binary_error: 0.153558	valid_1's binary_error: 0.196078
# [64]	training's binary_error: 0.153558	valid_1's binary_error: 0.196078
# [68]	training's binary_error: 0.151685	valid_1's binary_error: 0.196078
# [72]	training's binary_error: 0.151685	valid_1's binary_error: 0.196078
# Early stopping, best iteration is:
# [23]	training's binary_error: 0.134831	valid_1's binary_error: 0.19888
# Fitting model 12
# Training until validation scores don't improve for 50 rounds.
# [4]	training's binary_error: 0.157303	valid_1's binary_error: 0.215686
# [8]	training's binary_error: 0.166667	valid_1's binary_error: 0.212885
# [12]	training's binary_error: 0.166667	valid_1's binary_error: 0.19888
# [16]	training's binary_error: 0.149813	valid_1's binary_error: 0.196078
# [20]	training's binary_error: 0.14794	valid_1's binary_error: 0.184874
# [24]	training's binary_error: 0.146067	valid_1's binary_error: 0.19888
# [28]	training's binary_error: 0.144195	valid_1's binary_error: 0.201681
# [32]	training's binary_error: 0.149813	valid_1's binary_error: 0.204482
# [36]	training's binary_error: 0.149813	valid_1's binary_error: 0.204482
# [40]	training's binary_error: 0.14794	valid_1's binary_error: 0.204482
# [44]	training's binary_error: 0.149813	valid_1's binary_error: 0.196078
# [48]	training's binary_error: 0.14794	valid_1's binary_error: 0.193277
# [52]	training's binary_error: 0.149813	valid_1's binary_error: 0.187675
# [56]	training's binary_error: 0.151685	valid_1's binary_error: 0.196078
# [60]	training's binary_error: 0.151685	valid_1's binary_error: 0.193277
# [64]	training's binary_error: 0.149813	valid_1's binary_error: 0.190476
# [68]	training's binary_error: 0.149813	valid_1's binary_error: 0.193277
# Early stopping, best iteration is:
# [18]	training's binary_error: 0.151685	valid_1's binary_error: 0.184874

# %%
from time import gmtime, strftime
submName = strftime("%Y%m%d%H%M%S", gmtime()) + '_submission.csv'
sub.to_csv(submName, index=False)
