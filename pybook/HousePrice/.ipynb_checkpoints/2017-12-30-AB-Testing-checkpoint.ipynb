# %% [markdown]
# A/B test design
# Control units vs Test units
# Control variables
# Randomized A/B Testing Design
# Matched-Pair A/B Testing Design
#
#
# Remember that the main purpose of control variables is to make sure that you have a good match between
# treatment and control units. So that the comparison being made
# in the experiment is a good one.
#
# Five steps should be followed to determine which control variables should be used to set up the experiment.
#
# First, come up with **a list of potential variables.**
#
# Next, determine whether you have data for those variables **(Is variable data available?)**.
#
# Then make sure that the **connection between the target variable and each control variable is logical**.
#
# Next, test the **correlation between the control and target variables.**
#
# And lastly, **test correlation between other control variables** to avoid similar variables.

# %% [markdown]
# So how many control variables should you use?
#
# Well, there's no hard rule.
#
# It could be as few as one, or as many as five and sometimes more.
#
# Having too many control variables is usually worse for an experiment than having too few.
#
# A lurking (confounding) variable is when
# a variable is highly correlated with both target variable and
# another control variable.
#
# For example, you may look at some data
# and decide that the consumption of ice
#
# 16
# 00:00:46,620 --> 00:00:50,140
# cream is related to the number
# of deaths due to drowning.
#
# 17
# 00:00:50,140 --> 00:00:52,980
# Therefore, you may want to use
# the consumption of ice cream
#
# 18
# 00:00:52,980 --> 00:00:53,970
# as a control variable.
#
# 19
# 00:00:55,000 --> 00:00:57,640
# In reality,
# both the consumption of ice cream and
#
# 20
# 00:00:57,640 --> 00:01:01,410
# the number of deaths due to drowning
# are related to temperature.
#
# 21
# 00:01:01,410 --> 00:01:04,660
# Temperature is the lurking
# variable in this example.
#
# 22
# 00:01:04,660 --> 00:01:07,980
# When controlling for the temperature,
# you can observe that there's no
#
# 23
# 00:01:07,980 --> 00:01:11,610
# relationship between the consumption
# of ice cream and death from drowning.
#
# 24
# 00:01:12,660 --> 00:01:17,280
# In general, lurking variables can
# be avoided by using sound logic and
#
# 25
# 00:01:17,280 --> 00:01:19,900
# taking the time to think through
# your controlling variables

# %% [markdown]
# 1
# 00:00:00,370 --> 00:00:04,110
# Now that we have some of the basics and
# a vocabulary of experimental design
#
# 2
# 00:00:04,110 --> 00:00:07,790
# down, let's talk about two
# different types of experiments and
#
# 3
# 00:00:07,790 --> 00:00:10,060
# when you'd use each of them.
#
# 4
# 00:00:10,060 --> 00:00:12,960
# The two types of experiments that
# we'll be discussing in this course
#
# 5
# 00:00:12,960 --> 00:00:15,360
# are Randomized Design and
# Matched Pair Design.
#
# 6
# 00:00:16,600 --> 00:00:19,300
# Randomized design is a technique
# where the treatment and
#
# 7
# 00:00:19,300 --> 00:00:22,550
# control units are selected
# completely randomly.
#
# 8
# 00:00:22,550 --> 00:00:25,790
# This technique is used primarily
# in situations where there is
#
# 9
# 00:00:25,790 --> 00:00:29,470
# very little opportunity to control
# variables, and where the volume and
#
# 10
# 00:00:29,470 --> 00:00:33,365
# velocity of data is high enough
# that you're not worried about bias.
#
# 11
# 00:00:33,365 --> 00:00:35,930
# Website-based experiments and
#
# 12
# 00:00:35,930 --> 00:00:40,270
# phone system-based experiments are great
# examples of when the organization
#
# 13
# 00:00:40,270 --> 00:00:44,310
# has little ability to control who
# visits a site or who calls in.
#
# 14
# 00:00:44,310 --> 00:00:48,160
# And the volume is usually high
# enough that biases can be avoided.
#
# 15
# 00:00:48,160 --> 00:00:51,500
# Additionally, the cost per
# observation is usually very
#
# 16
# 00:00:51,500 --> 00:00:52,340
# low in these experiments.
#
# 17
# 00:00:53,340 --> 00:00:57,250
# In randomized experiments, whether an
# individual is in the treatment group or
#
# 18
# 00:00:57,250 --> 00:00:59,660
# control group is not predetermined.
#
# 19
# 00:00:59,660 --> 00:01:03,610
# It's determined on the fly in
# a completely random fashion.
#
# 20
# 00:01:03,610 --> 00:01:07,750
# For example, the traffic is routed
# randomly in such a way that people who
#
# 21
# 00:01:07,750 --> 00:01:11,420
# visit a website will see one of
# the two pages, the treatment page or
#
# 22
# 00:01:11,420 --> 00:01:13,300
# the control page.
#
# 23
# 00:01:13,300 --> 00:01:18,220
# In contrast, a matched pair is usually
# used when the volume of observations or
#
# 24
# 00:01:18,220 --> 00:01:20,100
# individuals is fairly low.
#
# 25
# 00:01:20,100 --> 00:01:22,700
# And the concern for
# bias is great, and the cost for
#
# 26
# 00:01:22,700 --> 00:01:24,660
# observation is high by comparison.
#
# 27
# 00:01:26,040 --> 00:01:27,910
# In this experimental design technique,
#
# 28
# 00:01:27,910 --> 00:01:31,770
# the treatments are matched by
# controls on a unit to unit basis.
#
# 29
# 00:01:31,770 --> 00:01:35,450
# Using a weighting of
# the identified control variables.
#
# 30
# 00:01:35,450 --> 00:01:39,980
# In our new product experiment, a matched
# pair design would involve taking each
#
# 31
# 00:01:39,980 --> 00:01:44,270
# treatment store and finding one or more
# similar control stores to match it to.
#
# 32
# 00:01:45,300 --> 00:01:48,350
# Analysis is done on
# a pair by pair basis,
#
# 33
# 00:01:48,350 --> 00:01:50,029
# then aggregated to a single result.
#
# 34
# 00:01:51,450 --> 00:01:55,400
# This unit by unit matching helps
# eliminate sources of bias, and
#
# 35
# 00:01:55,400 --> 00:01:57,600
# it increases confidence in results,
#
# 36
# 00:01:57,600 --> 00:01:59,940
# even with a lower number
# of total observations.
#
# 37
# 00:02:01,520 --> 00:02:05,740
# Unlike a completely randomized design, a
# matched pair design must be set up ahead
#
# 38
# 00:02:05,740 --> 00:02:10,280
# of time, and all units must be known
# before the start of the experiment.
#
# 39
# 00:02:10,280 --> 00:02:14,280
# For example, we would match each
# of the treatment candy stores with
#
# 40
# 00:02:14,280 --> 00:02:17,810
# one to two control stores in order to
# measure the impact of the treatment.

# %% [markdown]
# QUESTION 3 OF 3
# A sales organization wants to find out the impact on number of leads generated if they switch from contacting potential prospects via telephone calls to emails.
#
# This experiment could be done with either design, and there probably isn’t enough information to determine which would be better.
#
# If the experiment was done as a randomized design the advantage would be that the experiment would be considerably easier and cheaper to set up and analyze. The disadvantage would be that it would not directly account for possible bias.
#
# If the experiment was done as a matched pair design it would directly control for identified sources of bias (not just leaving random chance to deal with them). The drawback is that this type of experiment is more costly and time intensive to set up and analyze.

# %% [markdown]
# ### For how long should an experiment last?
#
# If Amazon knew that the majority
# of their customers shopped on their site once a week, then a week
# would represent a full cycle.
#
# If they ran the experiment in
# the middle of the day for two hours,
# they may not have a good representation
# of people who work during the day,
# and might have skewed the results. Having a full cycle of data reduces the
# chance of having bias in the responses.
#
# However, a full cycle is
# not always possible for
#
# 30
# 00:01:38,900 --> 00:01:40,810
# the length of an experiment.
#
# 31
# 00:01:40,810 --> 00:01:43,270
# The life of a cycle is not always known.
#
# 32
# 00:01:43,270 --> 00:01:46,510
# The analysts and business experts
# must use their best judges when
#
# 33
# 00:01:46,510 --> 00:01:49,390
# they're on a time frame that is
# long enough to not be biased.
#
# 34
# 00:01:49,390 --> 00:01:53,160
# But also fits within the time
# constraints of the business needs.
#
# 35
# 00:01:53,160 --> 00:01:56,630
# The amount of time that the experiment
# is going to run is important to nail
#
# 36
# 00:01:56,630 --> 00:01:59,250
# down as early as
# possible in the process.
#
# 37
# 00:01:59,250 --> 00:02:03,820
# Because that'll addicted how much past
# data you need to set up the experiment?
#
# 38
# 00:02:03,820 --> 00:02:07,810
# To do the analysis of an experiment, an
# equal amount of past data is needed for
#
# 39
# 00:02:07,810 --> 00:02:10,389
# baseline comparison as
# the length of the experiment.
